# %%
import os
import time
import pyautogui
import webbrowser
import re
from PIL import Image
import pandas as pd
from tqdm import tqdm
import math
from wilcoxon import sheets

try: os.chdir('Documents/Geospatial')
except: pass

# %%
malls = sheets.getGeo("Malls Half")

# %%
malls = malls.sort_values("Rank")

# %%
def bestStat(stat):
    if stat > 50:
        return "#3C8F41"
    elif stat < 11:
        return "#C10105"
    else: return "#000000"

def bestestStat(stat):
    if stat > 57 or stat < 4:
        return '<span style="color:#EFD065;">★ </span>'
    else: return ""

# %%
for i, mall in tqdm(enumerate(malls.to_dict("records"))):
    
    try:

        label = mall["Label"]
        abbr = " ".join(list(mall["Abbreviation"]))
            
        tags = [x.lower() for x in re.findall("[A-Z]+", label)]
        colors = ""

        for tag in tags:
            if tag in ["ew", "cg", "ns", "ne", "cc", "ce", "dt", "te", "je", "jw", "js", "cr", "cp", "pe", "pw", "se", "sw", "bp", "sn", "pt", "st"]:
                colors += "<span class=\"" + tag + "\">&nbsp;</span>"
        
        if mall["Rank"] < 4:
            color = "#000000"
            tcolor = "#FFFFFF"
        elif mall["Rank"] < 11:
            color = "#E10105"
            tcolor = "#FFFFFF"
        elif mall["Rank"] < 21:
            color = "#97CDE1"
            tcolor = "#000000"
        elif mall["Rank"] < 31:
            color = "#EFD065"
            tcolor = "#000000"
        elif mall["Rank"] < 46:
            color = "#E1E1E1"
            tcolor = "#000000"
        else:
            color = "#C17046"
            tcolor = "#FFFFFF"
            
        if mall["Rank"] < 61:
            ranking = """<div style="font-size: 40px; width: 70px; height: 70px; background: #EFD065; position: absolute; margin: 10px; border: 5px solid black; border-radius: 50%; display: grid; place-items: center;">""" + str(i+1) + """</div>"""
            planning = """<div style="font-size: 30px; width: 50px; height: 50px; background: #EFD065; position: absolute; margin: 10px; border: 5px solid black; border-radius: 50px; display: grid; place-items: center;">""" + mall["Planning Abbr"] + """</div>"""
        else:
            ranking = ""
            planning = ""

        html = """<!DOCTYPE HTML>
        <html>
        <head>
            <link href="https://fonts.googleapis.com/css?family=Public Sans" rel="stylesheet">
            <link href="https://fonts.googleapis.com/css?family=Roboto Mono" rel="stylesheet">
        </head>
        <style>
        html, body {
            margin: 0;
            font-size: 32px;
            font-family: Public Sans;
            line-height: 130%;
        }

        #card {
            height: 891px;
            width: 630px;
            padding: 30px;
            border: 1px solid black;
        }

        #img-container img {
            max-width: 100%;
            max-height: 100%;
        }

        #img-container {
            width: 590px;
            height: 380px;
            background-color: """ + color + """;
            display: grid;
            place-items: center;
            overflow: hidden;
            margin-bottom: 30px;
            border: 20px solid """ + color + """;
        }

        .top-label {
            border-top:1px solid black;
            border-bottom:1px solid black;
            float: left;
            display: flex;
            justify-content: center;
            margin-bottom: 30px;
        }

        .small {
            font-size: 16px;
            justify-content: center;
        }

        .small span {
            display: grid;
            place-items: center;
        }

        .ew, .cg {
            background-color: #009645;
            width: 100%;
        }

        .ns {
            background-color: #D42E12;
            width: 100%;
        }

        .ne {
            background-color: #9900AA;
            width: 100%;
        }

        .cc, .ce {
            background-color: #FA9E0D;
            width: 100%;
        }

        .dt {
            background-color: #005EC4;
            width: 100%;
        }

        .te {
            background-color: #9D5B25;
            width: 100%;
        }

        .je, .js, .jw {
            background-color: #0099AA;
            width: 100%;
        }

        .cr, .cp {
            background-color: #97C616;
            width: 100%;
        }
        
        .pe, .pw, .se, .sw, .bp, .pt, .st {
            background-color: #748477;
            width: 100%;
        }
        
        .sn {
            background-color: #F16D9F;
            width: 100%;
        }

        .attributes {
            width: 363px;
            display: inline-block;
            float: left;
            border: 1px solid black;
        }

        .values {
            width: 263px;
            display: inline-block;
            float: right;
            border: 1px solid black;
            text-align: right;
        }
        </style>
        <body>
            <div id="card">
                <div style="width: 500px; border-left:1px solid black;" class="top-label">""" + mall["Name"] + """</div>
                <div style="width: 128px; border-right:1px solid black;" class="top-label small">""" + colors + """<span style="position:absolute;font-size:1.1rem;color:white;text-align:justify;align-items:center;font-family:Monospace;">""" + abbr + """</span></div>

                <div id="img-container">
                    <img src="../MALLS IMG/""" + mall["Name"] + """.jpeg">
                    """ + planning + """
                </div>

                <div class="attributes">Latitude</div>
                <div class="values" style="color:""" + bestStat(mall["Latitude.1"]) + """;">""" + bestestStat(mall["Latitude.1"]) + str(round(mall["Latitude"],4))[:7] + """</div>

                <div class="attributes">Longitude</div>
                <div class="values" style="color:""" + bestStat(mall["Longitude.1"]) + """;">""" + bestestStat(mall["Longitude.1"]) + str(round(mall["Longitude"],4))[:9] + """</div>
                
                <div class="attributes">No. of Stores</div>
                <div class="values" style="color:""" + bestStat(mall["Stores.1"]) + """;">""" + bestestStat(mall["Stores.1"]) + str(int(mall["Stores"])) + """</div>
                
                <div class="attributes">No. of Floors</div>
                <div class="values" style="color:""" + bestStat(mall["Floors.1"]) + """;">""" + bestestStat(mall["Floors.1"]) + str(int(mall["Floors"])) + """</div>
                
                <div class="attributes">Nearby Halal Stores</div>
                <div class="values" style="color:""" + bestStat(mall["Halal.1"]) + """;">""" + bestestStat(mall["Halal.1"]) + str(int(mall["Halal"])) + """</div>
                
                <div class="attributes">Retail Area/sq.ft</div>
                <div class="values" style="color:""" + bestStat(mall["Area.1"]) + """;">""" + bestestStat(mall["Area.1"]) + str(round(mall["Area"]/1000,1)) + """k</div>
                
                <div class="attributes">Nearby Bus Services</div>
                <div class="values" style="color:""" + bestStat(mall["Bus.1"]) + """;">""" + bestestStat(mall["Bus.1"]) + str(int(mall["Bus"])) + """</div>
                
                <div class="attributes">Opening Year</div>
                <div class="values" style="color:""" + bestStat(mall["Opening year.1"]) + """;">""" + bestestStat(mall["Opening year.1"]) + str(int(mall["Opening year"])) + """</div>


            </div>
        </body>
        </html>"""

        file = open('MALLS HTML/' +  mall["Name"] + '.html','w')
        file.write(str(html))
        file.close()

        url = 'file:///Users/izzhafeez/Documents/Geospatial/MALLS HTML/' +  mall["Name"] + '.html'
        webbrowser.open_new_tab(url)

        time.sleep(2)

        screenshot = pyautogui.screenshot()
        screenshot.save('MALLS CARDS/' + mall["Name"] + ".png")

        im = Image.open('MALLS CARDS/' + mall["Name"] + ".png")
        im1 = im.crop((0,79,694,1025))
        im1.save('MALLS CLEAN CARDS/' + mall["Name"] + ".png")
    
    except Exception as e:
        print(mall["Name"] + "gave the error: " + str(e))
# Out:
# 60it [03:02,  3.04s/it]

# %%
def merge_images(files, n):
    
    images = [Image.open(x) for x in files]

    (width, height) = images[0].size

    result = Image.new('RGB', (n * width, n * height))
    
    for index, image in enumerate(images):
        result.paste(image, (width * (index % n), height * math.floor(index / n)))
    
    return result

# %%
for i in range(9):
    merge_images(["MALLS CLEAN CARDS/" + x + ".png" for x in malls["Name"].tolist()]
                  [i*9:(i+1)*9], 3).save("MALLS FINAL/Set" + str(i) + ".png")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-9b9db8dbdf85> in <module>
#       1 for i in range(9):
# ----> 2     merge_images(["MALLS CLEAN CARDS/" + x + ".png" for x in malls["Name"].tolist()]
#       3                   [i*9:(i+1)*9], 3).save("MALLS FINAL/Set" + str(i) + ".png")
#
# <ipython-input-14-dc9012b8bdcc> in merge_images(files, n)
#       3     images = [Image.open(x) for x in files]
#       4
# ----> 5     (width, height) = images[0].size
#       6
#       7     result = Image.new('RGB', (n * width, n * height))
#
# IndexError: list index out of range

# %%
merge_images(["MALLS CLEAN CARDS/" + x + ".png" for x in malls["Name"].tolist()]
                  [84:100], 4).save("MALLS FINAL/Set" + str(7) + ".png")

# %%
"$%0.2f" % (1.245,)
# Out:
# '$1.25'
